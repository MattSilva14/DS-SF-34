# %% [markdown]
# # DS-SF-34 | 05 | _k_-Nearest Neighbors | Codealong | Starter Code

# %%
import os

import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 10)
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 10)

from sklearn import preprocessing, neighbors, model_selection

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

# %%
df = pd.read_csv(os.path.join('..', 'datasets', 'dataset-05-iris.csv'))

# %%
df
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth    Species
# 0            5.1         3.5          1.4         0.2     Setosa
# 1            4.9         3.0          1.4         0.2     Setosa
# 2            4.7         3.2          1.3         0.2     Setosa
# 3            4.6         3.1          1.5         0.2     Setosa
# 4            5.0         3.6          1.4         0.2     Setosa
# ..           ...         ...          ...         ...        ...
# 145          6.7         3.0          5.2         2.3  Virginica
# 146          6.3         2.5          5.0         1.9  Virginica
# 147          6.5         3.0          5.2         2.0  Virginica
# 148          6.2         3.4          5.4         2.3  Virginica
# 149          5.9         3.0          5.1         1.8  Virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Part A | Activity | Iris Dataset | Exploratory Data Analysis

# %%
color = df.Species.map({'Setosa': 'red', 'Versicolor': 'green', 'Virginica': 'blue'})

# %%
df.plot(kind = 'box')

# %%
Q1 = df.SepalWidth.quantile(0.25)
Q3 = df.SepalWidth.quantile(0.75)

IQR = Q3 - Q1

IQR
# Out:
# 0.5

# %%
df.corr
# Out:
# <bound method DataFrame.corr of      SepalLength  SepalWidth  PetalLength  PetalWidth    Species
# 0            5.1         3.5          1.4         0.2     Setosa
# 1            4.9         3.0          1.4         0.2     Setosa
# 2            4.7         3.2          1.3         0.2     Setosa
# 3            4.6         3.1          1.5         0.2     Setosa
# 4            5.0         3.6          1.4         0.2     Setosa
# ..           ...         ...          ...         ...        ...
# 145          6.7         3.0          5.2         2.3  Virginica
# 146          6.3         2.5          5.0         1.9  Virginica
# 147          6.5         3.0          5.2         2.0  Virginica
# 148          6.2         3.4          5.4         2.3  Virginica
# 149          5.9         3.0          5.1         1.8  Virginica
#
# [150 rows x 5 columns]>

# %%
df.plot(kind = 'scatter', x = 'PetalLength', y = 'PetalWidth', c  = color, s = 100, figsize = (8, 8))

# %%
df.plot(kind = 'scatter', x = 'SepalLength', y = 'SepalWidth', s = 100, c = color, figsize = (8, 8))

# %%
pd.tools.plotting.scatter_matrix(df[['SepalLength','SepalWidth','PetalLength','PetalWidth']],c = color, figsize = (12, 12) )
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000015928F38A58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015928F968D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015928FF6CC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001592904F9B0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000159290B8DA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000159290B8DD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001592917BB00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000159291E0588>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000015929248A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015928CDEC18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000159292C8748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001592931D518>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001592938B9E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000159293A80B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000159294509E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000159294B7DD8>]], dtype=object)

# %% [markdown]
# ## Part B | Activity | Hand-Coded Classifier

# %%
c = df.Species

# %%
def my_first_classifier(row):
    if row.PetalLength < 2:
        return "Setosa"
    elif row.PetalLength < 4.8:
        return "Versicolor"
    else:
        return "Virginica"

# %%
c_hat = df.apply(my_first_classifier, axis = 1)

c_hat
# Out:
# 0         Setosa
# 1         Setosa
# 2         Setosa
# 3         Setosa
# 4         Setosa
#          ...
# 145    Virginica
# 146    Virginica
# 147    Virginica
# 148    Virginica
# 149    Virginica
# dtype: object

# %%
(c_hat != c).sum()
# Out:
# 7

# %%
pd.crosstab(c_hat, c, rownames = ['Hypothesized Class'], colnames = ['True Class'])
# Out:
# True Class          Setosa  Versicolor  Virginica
# Hypothesized Class
# Setosa                  50           0          0
# Versicolor               0          44          1
# Virginica                0           6         49

# %% [markdown]
# ## Part C | Classification Metrics

# %% [markdown]
# ### Accuracy

# %%
(c_hat == c).mean()
# Out:
# 0.95333333333333337

# %% [markdown]
# ### Misclassification rate

# %%
(c_hat != c).mean()
# Out:
# 0.046666666666666669

# %% [markdown]
# ## Part D | _k_-Nearest Neighbors (_k_-NN)

# %% [markdown]
# ### Feature matrix and response vector

# %% [markdown]
# - (http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html)

# %%
columns_X = ['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth']
X = df[columns_X]

scaler = preprocessing.MinMaxScaler().fit(X)

X = scaler.transform(X)

# %%
# TODO

# %%
c = df.Species

# %%
c
# Out:
# 0         Setosa
# 1         Setosa
# 2         Setosa
# 3         Setosa
# 4         Setosa
#          ...
# 145    Virginica
# 146    Virginica
# 147    Virginica
# 148    Virginica
# 149    Virginica
# Name: Species, dtype: object

# %% [markdown]
# ### _k_-Nearest Neighbors

# %% [markdown]
# - (http://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html)

# %%
model = neighbors.KNeighborsClassifier(n_neighbors = 1).\
    fit(X, c)

# %% [markdown]
# You can measure the precision of your prediction with `.score()`

# %%
model.score(X, c)

# %%
c_hat = model.predict(X)

# %%
(c_hat == c).mean()

# %%
pd.crosstab(c_hat, c, rownames = ['Hypothesized Class'], colnames = ['True Class'])

# %% [markdown]
# ### Train/test sets

# %% [markdown]
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.sample.html)

# %% [markdown]
# 50% of the dataset to train the model; the rest to test the model

# %%
train_df = df.sample(frac = .5, random_state = 0).sort_index()

# %%
train_df

# %%
test_df = df.drop(train_df.index)

# %% [markdown]
# ### Feature matrix `train_X` and response vector `train_c`

# %%
train_X = train_df[columns_X]

scaler = preprocessing.MinMaxScaler().fit(train_X)
train_X = scaler.transform(train_X)

train_c = train_df.Species

# %% [markdown]
# ### Feature matrix `test_X` and response vector `test_c`

# %% [markdown]
# - (http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html)
# - (http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.KFold.html)

# %%
# TODO

# %%
k_cv = 5 # 5-fold CV
k_nn = range(1, train_df.shape[0] * (k_cv - 1) / k_cv) # k-NN

gs = model_selection.GridSearchCV(
    estimator = neighbors.KNeighborsClassifier(),
    param_grid = {'n_neighbors': k_nn, 'weights': ['uniform', 'distance']},
    cv = model_selection.KFold(n_splits = k_cv, shuffle = True, random_state = 0)
)

gs.fit(train_X, train_c)

# %%
gs.cv_results_

# %%
gs.cv_results_.keys()

# %%
gs.best_score_

# %%
gs.best_params_

# %%
gs.best_estimator_

# %%
gs.score(train_X, train_c)

# %%
gs.score(test_X, test_c)

# %% [markdown]
# ## Final model

# %%
# TODO
