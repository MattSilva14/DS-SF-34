# %%
import os

import numpy as np

import pandas as pd
pd.set_option('display.max_rows', 37)
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 37)

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

import re

# %%
df = pd.read_csv(os.path.join('datasets', 'dataset-06-storms.csv.gz'), encoding='latin')
# Out:
# C:\Users\Matt\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (2,9,10,11,12,16,17,27,28,29,30,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df
# Out:
#         STATE__            BGN_DATE     BGN_TIME TIME_ZONE  COUNTY  \
# 0           1.0   4/18/1950 0:00:00          130       CST    97.0
# 1           1.0   4/18/1950 0:00:00          145       CST     3.0
# 2           1.0   2/20/1951 0:00:00         1600       CST    57.0
# 3           1.0    6/8/1951 0:00:00          900       CST    89.0
# 4           1.0  11/15/1951 0:00:00         1500       CST    43.0
# 5           1.0  11/15/1951 0:00:00         2000       CST    77.0
# 6           1.0  11/16/1951 0:00:00          100       CST     9.0
# 7           1.0   1/22/1952 0:00:00          900       CST   123.0
# 8           1.0   2/13/1952 0:00:00         2000       CST   125.0
# 9           1.0   2/13/1952 0:00:00         2000       CST    57.0
# 10          1.0   2/13/1952 0:00:00         2030       CST    43.0
# 11          1.0   2/13/1952 0:00:00         2030       CST     9.0
# 12          1.0   2/13/1952 0:00:00         2130       CST    73.0
# ...

# %%
df.columns
# Out:
# Index(['STATE__', 'BGN_DATE', 'BGN_TIME', 'TIME_ZONE', 'COUNTY', 'COUNTYNAME',
#        'STATE', 'EVTYPE', 'BGN_RANGE', 'BGN_AZI', 'BGN_LOCATI', 'END_DATE',
#        'END_TIME', 'COUNTY_END', 'COUNTYENDN', 'END_RANGE', 'END_AZI',
#        'END_LOCATI', 'LENGTH', 'WIDTH', 'F', 'MAG', 'FATALITIES', 'INJURIES',
#        'PROPDMG', 'PROPDMGEXP', 'CROPDMG', 'CROPDMGEXP', 'WFO', 'STATEOFFIC',
#        'ZONENAMES', 'LATITUDE', 'LONGITUDE', 'LATITUDE_E', 'LONGITUDE_',
#        'REMARKS', 'REFNUM'],
#       dtype='object')

# %%
list(df)
# Out:
# ['STATE__',
#  'BGN_DATE',
#  'BGN_TIME',
#  'TIME_ZONE',
#  'COUNTY',
#  'COUNTYNAME',
#  'STATE',
#  'EVTYPE',
#  'BGN_RANGE',
#  'BGN_AZI',
#  'BGN_LOCATI',
#  'END_DATE',
#  'END_TIME',
#  'COUNTY_END',
#  'COUNTYENDN',
#  'END_RANGE',
#  'END_AZI',
#  'END_LOCATI',
#  'LENGTH',
#  'WIDTH',
#  'F',
#  'MAG',
#  'FATALITIES',
#  'INJURIES',
#  'PROPDMG',
#  'PROPDMGEXP',
#  'CROPDMG',
#  'CROPDMGEXP',
#  'WFO',
#  'STATEOFFIC',
#  'ZONENAMES',
#  'LATITUDE',
#  'LONGITUDE',
#  'LATITUDE_E',
#  'LONGITUDE_',
#  'REMARKS',
#  'REFNUM']

# %%
df.dtypes
# Out:
# STATE__       float64
# BGN_DATE       object
# BGN_TIME       object
# TIME_ZONE      object
# COUNTY        float64
# COUNTYNAME     object
# STATE          object
# EVTYPE         object
# BGN_RANGE     float64
# BGN_AZI        object
# BGN_LOCATI     object
# END_DATE       object
# END_TIME       object
# COUNTY_END    float64
# COUNTYENDN    float64
# END_RANGE     float64
# END_AZI        object
# END_LOCATI     object
# LENGTH        float64
# WIDTH         float64
# F             float64
# MAG           float64
# FATALITIES    float64
# INJURIES      float64
# PROPDMG       float64
# PROPDMGEXP     object
# CROPDMG       float64
# CROPDMGEXP     object
# WFO            object
# STATEOFFIC     object
# ZONENAMES      object
# LATITUDE      float64
# LONGITUDE     float64
# LATITUDE_E    float64
# LONGITUDE_    float64
# REMARKS        object
# REFNUM        float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# STATE__            0
# BGN_DATE           0
# BGN_TIME           0
# TIME_ZONE          0
# COUNTY             0
# COUNTYNAME      1589
# STATE              0
# EVTYPE             0
# BGN_RANGE          0
# BGN_AZI       547332
# BGN_LOCATI    287743
# END_DATE      243411
# END_TIME      238978
# COUNTY_END         0
# COUNTYENDN    902297
# END_RANGE          0
# END_AZI       724837
# END_LOCATI    499225
# LENGTH             0
# WIDTH              0
# F             843563
# MAG                0
# FATALITIES         0
# INJURIES           0
# PROPDMG            0
# PROPDMGEXP    465934
# CROPDMG            0
# CROPDMGEXP    618413
# WFO           142069
# STATEOFFIC    248769
# ZONENAMES     594029
# LATITUDE          47
# LONGITUDE          0
# LATITUDE_E        40
# LONGITUDE_         0
# REMARKS       287433
# REFNUM             0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 6645709

# %%
df_2 = df.loc[:, pd.notnull(df).sum()>len(df)*.8]

# %%
df_2
# Out:
#         STATE__            BGN_DATE     BGN_TIME TIME_ZONE  COUNTY  \
# 0           1.0   4/18/1950 0:00:00          130       CST    97.0
# 1           1.0   4/18/1950 0:00:00          145       CST     3.0
# 2           1.0   2/20/1951 0:00:00         1600       CST    57.0
# 3           1.0    6/8/1951 0:00:00          900       CST    89.0
# 4           1.0  11/15/1951 0:00:00         1500       CST    43.0
# 5           1.0  11/15/1951 0:00:00         2000       CST    77.0
# 6           1.0  11/16/1951 0:00:00          100       CST     9.0
# 7           1.0   1/22/1952 0:00:00          900       CST   123.0
# 8           1.0   2/13/1952 0:00:00         2000       CST   125.0
# 9           1.0   2/13/1952 0:00:00         2000       CST    57.0
# 10          1.0   2/13/1952 0:00:00         2030       CST    43.0
# 11          1.0   2/13/1952 0:00:00         2030       CST     9.0
# 12          1.0   2/13/1952 0:00:00         2130       CST    73.0
# ...

# %%
df_2.isnull().sum()
# Out:
# STATE__            0
# BGN_DATE           0
# BGN_TIME           0
# TIME_ZONE          0
# COUNTY             0
# COUNTYNAME      1589
# STATE              0
# EVTYPE             0
# BGN_RANGE          0
# COUNTY_END         0
# END_RANGE          0
# LENGTH             0
# WIDTH              0
# MAG                0
# FATALITIES         0
# INJURIES           0
# PROPDMG            0
# CROPDMG            0
# WFO           142069
# LATITUDE          47
# LONGITUDE          0
# LATITUDE_E        40
# LONGITUDE_         0
# REFNUM             0
# dtype: int64

# %%
df_3 = df[['EVTYPE', 'FATALITIES', 'INJURIES', 'PROPDMG', 'CROPDMG', 'PROPDMGEXP', 'CROPDMGEXP']]

# %%
df_3
# Out:
#                 EVTYPE  FATALITIES  INJURIES  PROPDMG  CROPDMG PROPDMGEXP  \
# 0              TORNADO         0.0      15.0     25.0      0.0          K
# 1              TORNADO         0.0       0.0      2.5      0.0          K
# 2              TORNADO         0.0       2.0     25.0      0.0          K
# 3              TORNADO         0.0       2.0      2.5      0.0          K
# 4              TORNADO         0.0       2.0      2.5      0.0          K
# 5              TORNADO         0.0       6.0      2.5      0.0          K
# 6              TORNADO         0.0       1.0      2.5      0.0          K
# 7              TORNADO         0.0       0.0      2.5      0.0          K
# 8              TORNADO         1.0      14.0     25.0      0.0          K
# 9              TORNADO         0.0       0.0     25.0      0.0          K
# 10             TORNADO         0.0       3.0      2.5      0.0          M
# 11             TORNADO         0.0       3.0      2.5      0.0          M
# ...

# %%
df_3.max()
# Out:
# FATALITIES     583.0
# INJURIES      1700.0
# PROPDMG       5000.0
# CROPDMG        990.0
# dtype: float64

# %%
df_3.plot(kind = 'box')

# %%
df_3.groupby('EVTYPE').sum()
# Out:
#                         FATALITIES  INJURIES  PROPDMG  CROPDMG
# EVTYPE
#    HIGH SURF ADVISORY          0.0       0.0    200.0     0.00
#  COASTAL FLOOD                 0.0       0.0      0.0     0.00
#  FLASH FLOOD                   0.0       0.0     50.0     0.00
#  LIGHTNING                     0.0       0.0      0.0     0.00
#  TSTM WIND                     0.0       0.0    108.0     0.00
#  TSTM WIND (G45)               0.0       0.0      8.0     0.00
#  WATERSPOUT                    0.0       0.0      0.0     0.00
#  WIND                          0.0       0.0      0.0     0.00
# ?                              0.0       0.0      5.0     0.00
# ABNORMAL WARMTH                0.0       0.0      0.0     0.00
# ABNORMALLY DRY                 0.0       0.0      0.0     0.00
# ABNORMALLY WET                 0.0       0.0      0.0     0.00
# ACCUMULATED SNOWFALL           0.0       0.0      0.0     0.00
# AGRICULTURAL FREEZE            0.0       0.0      0.0    28.82
# ...

# %%
def is_in_it(evtype):
    return "ORN" in evtype

# %%
evtypes = pd.Series(df_3.EVTYPE.unique())

evtypes[evtypes.apply(is_in_it)]
# Out:
# 0                         TORNADO
# 23                     TORNADO F0
# 177                      TORNADOS
# 199            WATERSPOUT/TORNADO
# 201            WATERSPOUT TORNADO
# 204            WATERSPOUT-TORNADO
# 206    TORNADOES, TSTM WIND, HAIL
# 273              COLD AIR TORNADO
# 314           WATERSPOUT/ TORNADO
# 354                    TORNADO F3
# 356                       TORNDAO
# 360                    TORNADO F1
# 398            TORNADO/WATERSPOUT
# 441                    TORNADO F2
# 532                     TORNADOES
# 965                TORNADO DEBRIS
# dtype: object

# %%
df_4 = df_3[(df_3['FATALITIES'] != 0) & (df_3['INJURIES'] !=0)]

# %%
def is_in_it(evtype):
    return "ORN" in evtype

# %%
evtypes = pd.Series(df_4.EVTYPE.unique())

evtypes[evtypes.apply(is_in_it)]
# Out:
# 0                TORNADO
# 26    WATERSPOUT/TORNADO
# dtype: object

# %%
df_4
# Out:
#                    EVTYPE  FATALITIES  INJURIES  PROPDMG  CROPDMG PROPDMGEXP  \
# 8                 TORNADO         1.0      14.0    25.00      0.0          K
# 12                TORNADO         1.0      26.0   250.00      0.0          K
# 15                TORNADO         4.0      50.0    25.00      0.0          K
# 25                TORNADO         1.0       8.0    25.00      0.0          K
# 33                TORNADO         6.0     195.0     2.50      0.0          M
# 35                TORNADO         7.0      12.0   250.00      0.0          K
# 37                TORNADO         2.0       3.0    25.00      0.0          K
# 69                TORNADO         5.0      20.0     2.50      0.0          M
# 93                TORNADO        25.0     200.0     2.50      0.0          M
# 121               TORNADO         2.0      90.0     0.25      0.0          K
# 156               TORNADO         4.0      15.0    25.00      0.0          K
# ...

# %%
df_4.min()
# Out:
# FATALITIES    1.0
# INJURIES      1.0
# PROPDMG       0.0
# CROPDMG       0.0
# dtype: float64
