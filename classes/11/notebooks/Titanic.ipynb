# %%
import os

import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 15)
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 15)

import statsmodels.api as sm
import statsmodels.formula.api as smf

from sklearn import linear_model

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

# %%
df = pd.read_csv('titanic-train.csv')

# %%
df
# Out:
#      Unnamed: 0  Survived  Pclass  \
# 0          1302         1       1
# 1            17         0       3
# 2          1049         1       1
# 3           388         1       3
# 4          1060         1       2
# 5           328         0       2
# 6           729         1       3
# ..          ...       ...     ...
# 866         865         0       2
# 867         135         0       2
# 868         382         0       3
# 869         529         0       1
# 870        1215         1       1
# 871         923         1       2
# 872        1228         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                Earnshaw, Mrs. Boulton (Olive Potter)  female  23.0      0
# 1                    van Billiard, Master. Walter John    male  11.5      1
# 2                        Frauenthal, Dr. Henry William    male  50.0      2
# 3                                   Stranden, Mr. Juho    male  31.0      0
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0       0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            172
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Embarked         2
# PassengerId      0
# dtype: int64

# %%
df_2 = df.dropna()

# %%
df_2.isnull().sum()
# Out:
# Unnamed: 0     0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# PassengerId    0
# dtype: int64

# %%
df_2.describe()
# Out:
#         Unnamed: 0    Survived      Pclass         Age       SibSp  \
# count   698.000000  698.000000  698.000000  698.000000  698.000000
# mean    647.820917    0.418338    2.216332   29.457856    0.505731
# std     379.477562    0.493640    0.840453   14.181381    0.911017
# min       1.000000    0.000000    1.000000    0.166700    0.000000
# 25%     318.250000    0.000000    1.000000   21.000000    0.000000
# 50%     640.500000    0.000000    2.000000   28.000000    0.000000
# 75%     971.750000    1.000000    3.000000   38.000000    1.000000
# max    1307.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare  PassengerId
# count  698.000000  698.000000   698.000000
# mean     0.434097   35.464971   647.820917
# std      0.825932   54.115270   379.477562
# min      0.000000    0.000000     1.000000
# 25%      0.000000    8.050000   318.250000
# 50%      0.000000   15.741700   640.500000
# 75%      1.000000   34.375000   971.750000
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0    Survived      Pclass         Age       SibSp  \
# count   873.000000  873.000000  873.000000  701.000000  873.000000
# mean    648.357388    0.392898    2.300115   29.560747    0.469645
# std     377.179578    0.488674    0.837325   14.255972    0.932003
# min       1.000000    0.000000    1.000000    0.166700    0.000000
# 25%     322.000000    0.000000    2.000000   21.000000    0.000000
# 50%     638.000000    0.000000    3.000000   28.000000    0.000000
# 75%     972.000000    1.000000    3.000000   38.000000    1.000000
# max    1307.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare  PassengerId
# count  873.000000  872.000000   873.000000
# mean     0.387171   32.368950   648.357388
# std      0.831667   50.535715   377.179578
# min      0.000000    0.000000     1.000000
# 25%      0.000000    7.895800   322.000000
# 50%      0.000000   14.479150   638.000000
# 75%      0.000000   30.017700   972.000000
# ...

# %%
df.corr()
# Out:
#              Unnamed: 0  Survived    Pclass       Age     SibSp     Parch  \
# Unnamed: 0     1.000000  0.006311  0.025241  0.020005  0.001659  0.019943
# Survived       0.006311  1.000000 -0.338951 -0.034977 -0.012812  0.107791
# Pclass         0.025241 -0.338951  1.000000 -0.377474  0.064589  0.000924
# Age            0.020005 -0.034977 -0.377474  1.000000 -0.262496 -0.161495
# SibSp          0.001659 -0.012812  0.064589 -0.262496  1.000000  0.358425
# Parch          0.019943  0.107791  0.000924 -0.161495  0.358425  1.000000
# Fare          -0.028013  0.257220 -0.557365  0.139542  0.136756  0.189630
# PassengerId    1.000000  0.006311  0.025241  0.020005  0.001659  0.019943
#
#                  Fare  PassengerId
# Unnamed: 0  -0.028013     1.000000
# Survived     0.257220     0.006311
# Pclass      -0.557365     0.025241
# Age          0.139542     0.020005
# SibSp        0.136756     0.001659
# Parch        0.189630     0.019943
# Fare         1.000000    -0.028013
# ...

# %%
smf.ols(formula = 'Survived ~ Pclass', data = df).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               Survived   R-squared:                       0.115
# Model:                            OLS   Adj. R-squared:                  0.114
# Method:                 Least Squares   F-statistic:                     113.1
# Date:                Wed, 24 May 2017   Prob (F-statistic):           6.54e-25
# Time:                        21:16:55   Log-Likelihood:                -559.84
# No. Observations:                 873   AIC:                             1124.
# Df Residuals:                     871   BIC:                             1133.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      0.8479      0.046     18.620      0.000         0.759     0.937
# ...

# %%
smf.ols(formula = 'Survived ~ Age', data = df).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               Survived   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.8562
# Date:                Wed, 24 May 2017   Prob (F-statistic):              0.355
# Time:                        21:16:56   Log-Likelihood:                -499.12
# No. Observations:                 701   AIC:                             1002.
# Df Residuals:                     699   BIC:                             1011.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      0.4552      0.043     10.595      0.000         0.371     0.540
# ...

# %%
smf.ols(formula = 'Survived ~Fare', data = df).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               Survived   R-squared:                       0.066
# Model:                            OLS   Adj. R-squared:                  0.065
# Method:                 Least Squares   F-statistic:                     61.64
# Date:                Wed, 24 May 2017   Prob (F-statistic):           1.21e-14
# Time:                        21:16:56   Log-Likelihood:                -582.74
# No. Observations:                 872   AIC:                             1169.
# Df Residuals:                     870   BIC:                             1179.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      0.3128      0.019     16.457      0.000         0.276     0.350
# ...

# %%
smf.ols(formula = 'Survived ~ Parch', data = df).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               Survived   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     10.24
# Date:                Wed, 24 May 2017   Prob (F-statistic):            0.00142
# Time:                        21:16:57   Log-Likelihood:                -608.01
# No. Observations:                 873   AIC:                             1220.
# Df Residuals:                     871   BIC:                             1230.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      0.3684      0.018     20.297      0.000         0.333     0.404
# ...

# %%
smf.ols(formula = 'Survived ~ PassengerId', data = df).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               Survived   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                   0.03470
# Date:                Wed, 24 May 2017   Prob (F-statistic):              0.852
# Time:                        21:16:57   Log-Likelihood:                -613.10
# No. Observations:                 873   AIC:                             1230.
# Df Residuals:                     871   BIC:                             1240.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Intercept       0.3876      0.033     11.773      0.000         0.323     0.452
# ...

# %%
smf.ols(formula = 'Survived ~ Parch + Age + Pclass + Sex + SibSp', data = df).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               Survived   R-squared:                       0.377
# Model:                            OLS   Adj. R-squared:                  0.372
# Method:                 Least Squares   F-statistic:                     84.00
# Date:                Wed, 24 May 2017   Prob (F-statistic):           5.27e-69
# Time:                        21:16:58   Log-Likelihood:                -333.88
# No. Observations:                 701   AIC:                             679.8
# Df Residuals:                     695   BIC:                             707.1
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Intercept       1.3104      0.068     19.136      0.000         1.176     1.445
# ...

# %%
smf.ols(formula = 'Survived ~ Age + Pclass + Sex + SibSp', data = df).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               Survived   R-squared:                       0.376
# Model:                            OLS   Adj. R-squared:                  0.373
# Method:                 Least Squares   F-statistic:                     105.0
# Date:                Wed, 24 May 2017   Prob (F-statistic):           5.72e-70
# Time:                        21:16:58   Log-Likelihood:                -334.05
# No. Observations:                 701   AIC:                             678.1
# Df Residuals:                     696   BIC:                             700.9
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Intercept       1.3178      0.067     19.589      0.000         1.186     1.450
# ...

# %%
df['youngman'] = df['sex'] = 'Male' and df['Age'] < 30

# %%
df.youngman.sum()
# Out:
# 386

# %%
df[ ['Survived', 'youngman'] ].sum()
# Out:
# Survived    343.0
# youngman    386.0
# dtype: float64

# %%
df['oldlady'] = df['sex'] = 'female' and df['Age'] > 50
# Out:
# C:\Users\Matt\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df.oldlady.sum()
# Out:
# 61

# %%
df[ ['Survived', 'oldlady'] ].sum()
# Out:
# Survived    343.0
# oldlady      61.0
# dtype: float64

# %%
smf.ols(formula = 'Survived ~ youngman', data = df).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               Survived   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.3663
# Date:                Wed, 24 May 2017   Prob (F-statistic):              0.545
# Time:                        21:17:03   Log-Likelihood:                -612.93
# No. Observations:                 873   AIC:                             1230.
# Df Residuals:                     871   BIC:                             1239.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------
# ...

# %%
df['richguy'] = df['Sex'] = 'male' and df['Pclass'] < 2

# %%
df.richguy
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4      False
# 5      False
# 6      False
#        ...
# 866    False
# 867    False
# 868    False
# 869     True
# 870     True
# 871    False
# 872    False
# Name: richguy, dtype: bool

# %%
smf.ols(formula = 'Survived ~ richguy', data = df).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               Survived   R-squared:                       0.090
# Model:                            OLS   Adj. R-squared:                  0.089
# Method:                 Least Squares   F-statistic:                     85.79
# Date:                Wed, 24 May 2017   Prob (F-statistic):           1.52e-19
# Time:                        21:17:05   Log-Likelihood:                -572.11
# No. Observations:                 873   AIC:                             1148.
# Df Residuals:                     871   BIC:                             1158.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------
# ...

# %%
df.corr()
# Out:
#              Unnamed: 0  Survived    Pclass       Sex       Age     SibSp  \
# Unnamed: 0     1.000000  0.006311  0.025241 -0.015120  0.020005  0.001659
# Survived       0.006311  1.000000 -0.338951  0.299439 -0.034977 -0.012812
# Pclass         0.025241 -0.338951  1.000000 -0.885321 -0.377474  0.064589
# Sex           -0.015120  0.299439 -0.885321  1.000000  0.350223 -0.038605
# Age            0.020005 -0.034977 -0.377474  0.350223  1.000000 -0.262496
# SibSp          0.001659 -0.012812  0.064589 -0.038605 -0.262496  1.000000
# Parch          0.019943  0.107791  0.000924 -0.012349 -0.161495  0.358425
# Fare          -0.028013  0.257220 -0.557365  0.597318  0.139542  0.136756
# PassengerId    1.000000  0.006311  0.025241 -0.015120  0.020005  0.001659
# youngman      -0.003310  0.020502  0.179577 -0.207075 -0.784073  0.135487
# sex            0.042102  0.018706 -0.254002  0.240733  0.628577 -0.041718
# oldlady        0.042102  0.018706 -0.254002  0.240733  0.628577 -0.041718
# ...

# %%
df['poorguy'] = df['sex'] = 'male' and df['Pclass'] > 1

# %%
df.poorguy.sum()
# Out:
# 659

# %%
smf.ols(formula = 'Survived ~ poorguy', data = df).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               Survived   R-squared:                       0.090
# Model:                            OLS   Adj. R-squared:                  0.089
# Method:                 Least Squares   F-statistic:                     85.79
# Date:                Wed, 24 May 2017   Prob (F-statistic):           1.52e-19
# Time:                        21:17:08   Log-Likelihood:                -572.11
# No. Observations:                 873   AIC:                             1148.
# Df Residuals:                     871   BIC:                             1158.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------
# ...

# %%
smf.ols(formula = 'Survived ~ Age + Pclass + Sex + SibSp', data = df).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               Survived   R-squared:                       0.160
# Model:                            OLS   Adj. R-squared:                  0.155
# Method:                 Least Squares   F-statistic:                     33.10
# Date:                Wed, 24 May 2017   Prob (F-statistic):           2.71e-25
# Time:                        21:17:16   Log-Likelihood:                -438.51
# No. Observations:                 701   AIC:                             887.0
# Df Residuals:                     696   BIC:                             909.8
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Intercept       1.1649      0.127      9.180      0.000         0.916     1.414
# ...

# %%
df = df.dropna()

# %%
X = df[ ['Age', 'Pclass', 'Fare', 'poorguy','richguy', 'PassengerId']]
c = df.Survived

model = linear_model.LogisticRegression(penalty = 'l1').\
    fit(X, c)

# %%
model.score(X, c)
# Out:
# 0.71346704871060174

# %%
c_hat = model.predict(X)

pd.crosstab(c_hat,
    c,
    rownames = ['Hypothesized Class'],
    colnames = ['True Class'])
# Out:
# True Class            0    1
# Hypothesized Class
# 0                   344  138
# 1                    62  154

# %%
dfTest = pd.read_csv('titanic-test.csv')

# %%
dfTest
# Out:
#      Unnamed: 0  Pclass                                             Name  \
# 0             0       2                 Frost, Mr. Anthony Wood "Archie"
# 1             2       3                                 Danoff, Mr. Yoto
# 2             4       2                    Jefferys, Mr. Clifford Thomas
# 3             6       3                                  Sage, Miss. Ada
# 4            12       1                        Stahelin-Maeglin, Dr. Max
# 5            13       2                       Bateman, Rev. Robert James
# 6            15       3                         Conlon, Mr. Thomas Henry
# ..          ...     ...                                              ...
# 429        1288       3                                Cor, Mr. Liudevit
# 430        1291       3                             O'Brien, Mr. Timothy
# 431        1293       3                   Nieminen, Miss. Manta Josefina
# 432        1297       2      Renouf, Mrs. Peter Henry (Lillian Jefferys)
# ...

# %%
dfTest.dropna()
# Out:
#      Unnamed: 0  Pclass                                             Name  \
# 1             2       3                                 Danoff, Mr. Yoto
# 2             4       2                    Jefferys, Mr. Clifford Thomas
# 4            12       1                        Stahelin-Maeglin, Dr. Max
# 5            13       2                       Bateman, Rev. Robert James
# 6            15       3                         Conlon, Mr. Thomas Henry
# 7            16       3                           Heikkinen, Miss. Laina
# 9            20       2              Troutt, Miss. Edwina Celia "Winnie"
# ..          ...     ...                                              ...
# 428        1285       1      Douglas, Mrs. Walter Donald (Mahala Dutton)
# 429        1288       3                                Cor, Mr. Liudevit
# 431        1293       3                   Nieminen, Miss. Manta Josefina
# 432        1297       2      Renouf, Mrs. Peter Henry (Lillian Jefferys)
# ...

# %%
dfTest['poorguy'] = dfTest['Sex'] = 'male' and dfTest['Pclass'] > 1

# %%
dfTest['richguy'] = dfTest['Sex'] = 'male' and dfTest['Pclass'] < 2

# %%
dfTest['oldlady'] = dfTest['Sex'] = 'female' and dfTest['Age'] > 50

# %%
model.predict(dfTest)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-405-ad710b46570e> in <module>()
# ----> 1 model.predict(dfTest)
#
# C:\Users\Matt\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     334             Predicted class label per sample.
#     335         """
# --> 336         scores = self.decision_function(X)
#     337         if len(scores.shape) == 1:
#     338             indices = (scores > 0).astype(np.int)
#
# C:\Users\Matt\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in decision_function(self, X)
#     310                                  "yet" % {'name': type(self).__name__})
#     311
# --> 312         X = check_array(X, accept_sparse='csr')
#     313
#     314         n_features = self.coef_.shape[1]
#
# ...

# %%
dfTest.to_csv
# Out:
# <bound method DataFrame.to_csv of      Unnamed: 0  Pclass                                             Name  \
# 0             0       2                 Frost, Mr. Anthony Wood "Archie"
# 1             2       3                                 Danoff, Mr. Yoto
# 2             4       2                    Jefferys, Mr. Clifford Thomas
# 3             6       3                                  Sage, Miss. Ada
# 4            12       1                        Stahelin-Maeglin, Dr. Max
# 5            13       2                       Bateman, Rev. Robert James
# 6            15       3                         Conlon, Mr. Thomas Henry
# ..          ...     ...                                              ...
# 429        1288       3                                Cor, Mr. Liudevit
# 430        1291       3                             O'Brien, Mr. Timothy
# 431        1293       3                   Nieminen, Miss. Manta Josefina
# ...
